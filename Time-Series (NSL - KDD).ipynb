# %%
import pandas as pd 

test = pd.read_csv("/home/anujtiwari/Programming/QuantumML/Anomaly Detection Using QML/Datasets/KDDTest+.csv")
train = pd.read_csv("/home/anujtiwari/Programming/QuantumML/Anomaly Detection Using QML/Datasets/KDDTrain+.csv")


test.head()
# Out:
#   duration protocol_type service  flag  src_bytes  dst_bytes  land  \
# 0      tcp        telnet      SF   118       2425          0     0
# 1      udp       private      SF    44          0          0     0
# 2      tcp        telnet      S3     0         44          0     0
# 3      udp       private      SF    53         55          0     0
# 4      tcp       private      SH     0          0          0     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# 0               0       0    0  ...                0.38
# 1               0       0    0  ...                1.00
# 2               0       0    0  ...                0.31
# 3               0       0    0  ...                1.00
# 4               0       0    0  ...                0.06
#
#    dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                    0.12                    0.04
# 1                    0.01                    0.01
# 2                    0.61                    0.00
# ...

# %% [markdown]
# So, the thing is NSL-KDD dataset is not a time series dataset, it just has rows of connection logs, but as we need it for time series analysis, the time series need data to be:
# - Structured overtime (i.e time steps)
# - with each step having some summary of signal activity.
#
# <br>
# So now lets break the data into windows of size 100, 1 window size = 1 TimeStep

# %%
window_size = 100

def label_window(group): 
    if 'normal' in group['label'].values:
        return 'normal'
    else:       
        return 'anomaly'    
    
train['window_id'] = train.index // window_size
grouped = train.groupby('window_id')

# %%
print(train.shape)
print(train.index)
# Out:
# (11850, 43)
# RangeIndex(start=0, stop=11850, step=1)

# %%
# this code gives the name of all columns in the dataframe
column_names = train.columns.tolist()
print(column_names)
# Out:
# ['duration', 'protocol_type', 'service', 'flag', 'src_bytes', 'dst_bytes', 'land', 'wrong_fragment', 'urgent', 'hot', 'num_failed_logins', 'logged_in', 'num_compromised', 'root_shell', 'su_attempted', 'num_root', 'num_file_creations', 'num_shells', 'num_access_files', 'num_outbound_cmds', 'is_host_login', 'is_guest_login', 'count', 'srv_count', 'serror_rate', 'srv_serror_rate', 'rerror_rate', 'srv_rerror_rate', 'same_srv_rate', 'diff_srv_rate', 'srv_diff_host_rate', 'dst_host_count', 'dst_host_srv_count', 'dst_host_same_srv_rate', 'dst_host_diff_srv_rate', 'dst_host_same_src_port_rate', 'dst_host_srv_diff_host_rate', 'dst_host_serror_rate', 'dst_host_srv_serror_rate', 'dst_host_rerror_rate', 'dst_host_srv_rerror_rate', 'label', 'window_id']
